# %%
#analyse student exam scores with python

import numpy as np
scores=np.array([45,78,56,89,90,67,34,23,88,76,54,61,72,48,59,92,81,39,64,70])
average=np.mean(scores)
highest=np.max(scores)
lowest=np.min(scores)
print("Average Score:",average)
print("Lowest Score:",highest)
print("Lowest Score:",lowest)
pass_mark=50
print("\nPass/Fail Status")
for i in range(len(scores)):
  if scores[i]>= pass_mark:
    print("pass")
  else:
    print("fail")
print("\nGrades")
for i, s in enumerate(scores):
  if s >=90:
    grade="A"
  elif s >=75:
    grade="B"
  elif s >=60:
    grade="C"
  elif s >=50:
    grade="D"
  else:
    grade = "F"
  print("Student",i+1,"Grade:",grade)
# Out:
# Average Score: 64.3
# Lowest Score: 92
# Lowest Score: 23
#
# Pass/Fail Status
# fail
# pass
# pass
# pass
# pass
# pass
# fail
# fail
# pass
# pass
# pass
# pass
# pass
# fail
# pass
# pass
# pass
# fail
# pass
# pass
#
# Grades
# Student 1 Grade: F
# Student 2 Grade: B
# Student 3 Grade: D
# Student 4 Grade: B
# Student 5 Grade: A
# Student 6 Grade: C
# Student 7 Grade: F
# Student 8 Grade: F
# Student 9 Grade: B
# Student 10 Grade: B
# Student 11 Grade: D
# Student 12 Grade: C
# Student 13 Grade: C
# Student 14 Grade: F
# Student 15 Grade: D
# Student 16 Grade: A
# Student 17 Grade: B
# Student 18 Grade: F
# Student 19 Grade: C
# Student 20 Grade: C
