# %%
#total impedance of electrical circuit

import numpy as np
n = int(input("Enter number of components: "))
Z = []
for i in range(n):
    value = complex(input(f"Enter impedance Z{i+1} (example 10+5j): "))
    Z.append(value)
Z = np.array(Z)
choice = input("Enter connection type (series or parallel): ")
if choice == "series":
    Z_total = np.sum(Z)
    print("Total Series Impedance =", Z_total)
elif choice == "parallel":
    Z_total = 1 / np.sum(1/Z)
    print("Total Parallel Impedance =", Z_total)
else:
    print("Invalid connection type")
# Out:
# Enter number of components:  3
# Enter impedance Z1 (example 10+5j):  4+5j
# Enter impedance Z2 (example 10+5j):  6+7j
# Enter impedance Z3 (example 10+5j):  9-2j
# Enter connection type (series or parallel):  parallel
# Total Parallel Impedance = (2.542678151918559+1.6773688332028192j)
